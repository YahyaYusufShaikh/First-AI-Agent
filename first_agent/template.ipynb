# %%
# !pip install -U -q transformers datasets bitsandbytes trl peft huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

model_name = "mistralai/Mistral-7B-v0.3"
config_4bit = BitsAndBytesConfig(load_in_4bit=True)
model_4bit = AutoModelForCausalLM.from_pretrained(
                                        model_name,
                                        quantization_config=config_4bit,
                                        device_map="auto",
                                        trust_remote_code=True
                                                )

tokenizer = AutoTokenizer.from_pretrained(model_name, padding_side="left", trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
#       2 import torch
#       4 model_name = "mistralai/Mistral-7B-v0.3"
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2212, in _LazyModule.__getattr__(self, name)
#    2210 elif name in self._class_to_module:
#    2211     try:
# -> 2212         module = self._get_module(self._class_to_module[name])
#    2213         value = getattr(module, name)
#    2214     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2215         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2216         # non-Fast symbol from the same module when available. This lets us keep only one
#    2217         # backend tokenizer class while preserving legacy public names.
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2446, in _LazyModule._get_module(self, module_name)
#    2444     return importlib.import_module("." + module_name, self.__name__)
#    2445 except Exception as e:
# -> 2446     raise e
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2444, in _LazyModule._get_module(self, module_name)
#    2442 def _get_module(self, module_name: str):
#    2443     try:
# -> 2444         return importlib.import_module("." + module_name, self.__name__)
#    2445     except Exception as e:
#    2446         raise e
#
# File c:\Users\HP EliteBook\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\models\auto\modeling_auto.py:21
#      18 from typing import TYPE_CHECKING
#      20 from ...utils import logging
# ---> 21 from .auto_factory import (
#      22     _BaseAutoBackboneClass,
#      23     _BaseAutoModelClass,
#      24     _LazyAutoMapping,
#      25     auto_class_update,
#      26 )
#      27 from .configuration_auto import CONFIG_MAPPING_NAMES
#      30 if TYPE_CHECKING:
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:26
#      22 from typing import Any, TypeVar
#      24 from huggingface_hub import repo_exists
# ---> 26 from ...configuration_utils import PreTrainedConfig
#      27 from ...dynamic_module_utils import get_class_from_dynamic_module, resolve_trust_remote_code
#      28 from ...utils import (
#      29     CONFIG_NAME,
#      30     cached_file,
#    (...)
#      37     requires_backends,
#      38 )
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\configuration_utils.py:33
#      31 from . import __version__
#      32 from .dynamic_module_utils import custom_object_save
# ---> 33 from .generation.configuration_utils import GenerationConfig
#      34 from .modeling_gguf_pytorch_utils import load_gguf_checkpoint
#      35 from .modeling_rope_utils import RotaryEmbeddingConfigMixin
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:62
#      58 ALL_CACHE_IMPLEMENTATIONS = ALL_STATIC_CACHE_IMPLEMENTATIONS + DYNAMIC_CACHE_IMPLEMENTATIONS
#      61 if is_torch_available():
# ---> 62     from .logits_process import SynthIDTextWatermarkLogitsProcessor, WatermarkLogitsProcessor
#      65 class GenerationMode(ExplicitEnum):
#      66     """
#      67     Possible generation modes, downstream of the [`~generation.GenerationMixin.generate`] method.
#      68     """
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\transformers\generation\logits_process.py:21
#      18 from typing import TYPE_CHECKING, Any, cast
#      20 import numpy as np
# ---> 21 import torch
#      23 from .._typing import WhisperGenerationConfigLike
#      24 from ..utils import add_start_docstrings
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File c:\Users\HP EliteBook\anaconda3\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\HP EliteBook\anaconda3\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.
